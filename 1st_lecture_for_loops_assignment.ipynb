# %% [markdown]
# <a href="https://colab.research.google.com/github/jupsimar/Python-pandas/blob/main/1st_lecture_for_loops_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Please follow the instructions and get the answers you see on screenshots. There are many ways to achieve that. Remember, we are practicing for loops though; every single line of code needs to be explained

# %%
#import the libraries
import numpy as np
import pandas as pd

# %%
#Import colors
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

# %%
# Define a dictionary containing students data
data = {'Name': ['Endie', 'Ella', 'Elliot', 'Priyanka', 'John', 'Alison','Donald','Alex','Dora','Dori'],
                'Age': [21, 19, 20, 18,23,27,22,31,19,27],
                'Stream': ['Math', 'Commerce', 'Arts', 'Biology','Law','Law','Math','Arts','Commerce','Commerce'],
                'Percentage': [88, 92, 95, 70,92,78,56,88,71,91]}
  
# Convert the dictionary into DataFrame
df = pd.DataFrame(data, columns = ['Name', 'Age', 'Stream', 'Percentage'])

# %% [markdown]
# #Homework:

# %% [markdown]
# ###1st question:
# Print the name and the stream of all the entries in a dataframe

# %%
# Your code here should yield the following result:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###2nd question
# By using slicing technique we covered in class, please print the name and the stream of the first three students

# %%
# Your code here should yield the following result:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###3nd question
# By using slicing technique we covered in class, please print the name and the stream of the last student

# %%
# Your code here should yield the following result:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###4th question
#
# Print the name/names and the stream/streams of the person/people that is/are older than 18 and exclude the first row.
#
# You'll need to use a. index when creating a for loop and b. if statement inside your foor loop to filter ages that are > 18. You may find this article useful: https://www.datacamp.com/community/tutorials/for-loops-in-python

# %%
# Your code here should yield the following result:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###5th question
# Print the averages for age and percentage columns
#
# use for loop and np.array() technique

# %%
# Your code here should yield the following result:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###6th question
# Print the counts of students by stream
#
# use for loop and np.array() technique as well as .value_counts instead of .mean

# %%
# Your code here should yield the following result:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###7th question
# Print averages by stream (outer loop to get the streams, inner loop to get averages)

# %%
# Your code here should yield the following result:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **GREAT JOB**
